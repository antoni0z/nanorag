# %% [raw]
# ---
# description: Utility functions to be used throughout the modules
# output-file: utils.html
# title: Utils
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(hash_input)
# Out:
# ---
#
# [source](https://github.com/antoni0z/nanorag/blob/main/nanorag/utils.py#L10){target="_blank" style="float:right; font-size:smaller"}
#
# ### hash_input
#
# >      hash_input (input_data:str)
