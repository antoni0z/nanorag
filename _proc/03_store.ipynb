# %% [raw]
# ---
# description: Provides storage for documents
# output-file: store.html
# title: Store
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(BaseDocumentStore)
# Out:
# ---
#
# [source](https://github.com/antoni0z/nbdev_rag/blob/main/nbdev_rag/store.py#L12){target="_blank" style="float:right; font-size:smaller"}
#
# ### BaseDocumentStore
#
# >      BaseDocumentStore (documents:Dict[str,nbdev_rag.base.Document]={})
#
# Base class for document storage

# %%
#| echo: false
#| output: asis
show_doc(DocumentStore)
# Out:
# ---
#
# [source](https://github.com/antoni0z/nbdev_rag/blob/main/nbdev_rag/store.py#L35){target="_blank" style="float:right; font-size:smaller"}
#
# ### DocumentStore
#
# >      DocumentStore (documents:Dict[str,nbdev_rag.base.Document]={})
#
# Key value type document store that store documents by their id in a dictionary.
# Also checks for duplicates via hashing and doesn't admit them
