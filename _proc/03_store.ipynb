# %% [raw]
# ---
# description: Provides storage for documents
# output-file: store.html
# title: Store
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
from nbdev.showdoc import *

# %%
#| echo: false
#| output: asis
show_doc(BaseDocumentStore)
# Out:
# ---
#
# [source](https://github.com/antoni0z/nanorag/blob/main/nanorag/store.py#L20){target="_blank" style="float:right; font-size:smaller"}
#
# ### BaseDocumentStore
#
# >      BaseDocumentStore (documents:Dict[str,nanorag.base.Document]={})
#
# Base class for document storage

# %%
#| echo: false
#| output: asis
show_doc(DocumentStore)
# Out:
# ---
#
# [source](https://github.com/antoni0z/nanorag/blob/main/nanorag/store.py#L40){target="_blank" style="float:right; font-size:smaller"}
#
# ### DocumentStore
#
# >      DocumentStore
# >                     (documents:Union[List[nanorag.base.Document],nanorag.base.
# >                     Document]=[])
#
# Key value type document store that store documents by their id in a dictionary.
# Also checks for duplicates via hashing and doesn't admit them. Compatible with both nodes and documents.

# %%
#| echo: false
#| output: asis
show_doc(PostgresDocumentStore)
# Out:
# ---
#
# [source](https://github.com/antoni0z/nanorag/blob/main/nanorag/store.py#L115){target="_blank" style="float:right; font-size:smaller"}
#
# ### PostgresDocumentStore
#
# >      PostgresDocumentStore (db_uri, table_name='documents')
#
# Base class for document storage
