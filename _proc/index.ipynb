# %% [raw]
# ---
# description: A simple rag framework
# output-file: index.html
# title: nbdev_rag
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install nbdev_rag
# ```

# %% [markdown]
# ## How to use

# %% [markdown]
# First we can define a Document
