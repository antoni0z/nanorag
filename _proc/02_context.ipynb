# %% [raw]
# ---
# description: Set of classes that provide context about the models
# output-file: context.html
# title: Model Context
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(ModelContext)
# Out:
# ---
#
# [source](https://github.com/antoni0z/nanorag/blob/main/nanorag/context.py#L7){target="_blank" style="float:right; font-size:smaller"}
#
# ### ModelContext
#
# >      ModelContext (llm, embedding, tokenizer)
#
# Initialize self.  See help(type(self)) for accurate signature.
