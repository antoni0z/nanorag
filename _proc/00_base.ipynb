# %% [raw]
# ---
# description: Includes the main datastructures for Nodes and Documents.
# output-file: base.html
# title: base
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(BaseNode)
# Out:
# ---
#
# [source](https://github.com/antoni0z/nbdev_rag/blob/main/nbdev_rag/base.py#L12){target="_blank" style="float:right; font-size:smaller"}
#
# ### BaseNode
#
# >      BaseNode (metadata, model_context, prev_node=None, next_node=None,
# >                parent_node=None, child_node=[], embedding=[])
#
# Lowest level abstraction for storing interrelated pieces of information, building block for other types of nodes.

# %%
#| echo: false
#| output: asis
show_doc(TextNode)
# Out:
# ---
#
# [source](https://github.com/antoni0z/nbdev_rag/blob/main/nbdev_rag/base.py#L41){target="_blank" style="float:right; font-size:smaller"}
#
# ### TextNode
#
# >      TextNode (text, model_context, metadata, prev_node=None, next_node=None,
# >                parent_node=None, child_node=[], embedding=[], auto_embed=True)
#
# Class for creating chunks of Text that contain additional information like relationships of metadata, inheritance from
# BaseNode but geared specifically towards text

# %%
#| echo: false
#| output: asis
show_doc(Document)
# Out:
# ---
#
# [source](https://github.com/antoni0z/nbdev_rag/blob/main/nbdev_rag/base.py#L69){target="_blank" style="float:right; font-size:smaller"}
#
# ### Document
#
# >      Document (metadata={}, name=None, text=None, prev_node=None,
# >                next_node=None, parent_node=None, child_node=[], embedding=[])
#
# Class that serves as a way to group information that comes from different sources intended to be stored or integrated with other services
