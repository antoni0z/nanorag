# %% [raw]
# ---
# description: Module for handling interactions with llms
# output-file: llm.html
# title: LLM
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(LLM)
# Out:
# ---
#
# ### LLM
#
# >      LLM (model, tokenizer)
#
# Class for interacting and Loading llms, tested with hugging face ones and it works correctly

# %%
#| echo: false
#| output: asis
show_doc(PromptTemplate)
# Out:
# ---
#
# ### PromptTemplate
#
# >      PromptTemplate (template='A user provided this instructions')
#
# Class for prompt templating and adding intructions for an LLM
