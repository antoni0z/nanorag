# %% [raw]
# ---
# description: A module for importing data and converting it to a processable output
#   for the most typical file formats
# output-file: loaders.html
# title: Loaders
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(PDFLoader)
# Out:
# ---
#
# [source](https://github.com/antoni0z/nbdev_rag/blob/main/nbdev_rag/loaders.py#L16){target="_blank" style="float:right; font-size:smaller"}
#
# ### PDFLoader
#
# >      PDFLoader (path_dir:str)
#
# Accepts a dir or single path and converts its contents into documents that can be later used for storage and retrieval

# %%
#| echo: false
#| output: asis
show_doc(DocumentBridge)
# Out:
# ---
#
# [source](https://github.com/antoni0z/nbdev_rag/blob/main/nbdev_rag/loaders.py#L75){target="_blank" style="float:right; font-size:smaller"}
#
# ### DocumentBridge
#
# >      DocumentBridge (documents:List, context:nbdev_rag.context.ModelContext)
#
# Class for connecting a list of documents into its corresponding Nodes and relationships
