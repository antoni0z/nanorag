# %% [raw]
# ---
# description: A module for importing data and converting it to a processable output
#   for the most typical file formats
# output-file: loaders.html
# title: Loaders
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(PDFLoader)
# Out:
# ---
#
# [source](https://github.com/antoni0z/nanorag/blob/main/nanorag/loaders.py#L20){target="_blank" style="float:right; font-size:smaller"}
#
# ### PDFLoader
#
# >      PDFLoader (path_dir:str, store=None)
#
# Accepts a dir or single path and converts its contents into documents that can be later used for storage and retrieval

# %%
#| echo: false
#| output: asis
show_doc(DocumentBridge)
# Out:
# ---
#
# [source](https://github.com/antoni0z/nanorag/blob/main/nanorag/loaders.py#L122){target="_blank" style="float:right; font-size:smaller"}
#
# ### DocumentBridge
#
# >      DocumentBridge
# >                      (documents:Union[List[nanorag.base.Document],nanorag.base
# >                      .Document], context:nanorag.context.ModelContext)
#
# Class for connecting a list of documents into its corresponding Nodes and relationships
